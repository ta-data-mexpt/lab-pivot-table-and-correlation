# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd 
import numpy as np

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Open the ` Employee.csv` file and name your dataset `employee`

# %%
# your answer here
employee = pd.read_csv('Employee.csv')
employee.head(2)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30

# %% [markdown]
# #### What's the mean salary by department.
# ##### Tip : There are 2 ways to do it - one way is with and the other way is without pivot tables. Do it both ways.

# %%
# your answer here-1st way
employee.pivot_table(index=['Salary']).reset_index()
# Out:
#    Salary  Years
# 0      30    2.0
# 1      35    2.5
# 2      55    2.5
# 3      60    7.0
# 4      70    8.0

# %%
# your answer here-2nd way
employee.groupby(employee.Department).agg(np.mean).reset_index()
# Out:
#   Department     Years  Salary
# 0         HR  4.666667   45.00
# 1         IT  4.500000   48.75
# 2      Sales  2.500000   55.00

# %%
employee.groupby(employee.Department).agg({'Salary':'mean'}).reset_index()
# Out:
#   Department  Salary
# 0         HR   45.00
# 1         IT   48.75
# 2      Sales   55.00

# %%
employee.groupby(['Department']).agg ({'Salary':'mean'}).reset_index()
# Out:
#   Department  Salary
# 0         HR   45.00
# 1         IT   48.75
# 2      Sales   55.00

# %% [markdown]
# #### We want now to group the data by more than one column. Use Pandas pivot table function to select the mean salary by department and title

# %%
# your answer here
employee.pivot_table(index=['Department', 'Title']).reset_index()
# Out:
#   Department      Title  Salary  Years
# 0         HR         VP    70.0    8.0
# 1         HR    analyst    32.5    3.0
# 2         IT         VP    70.0    8.0
# 3         IT    analyst    32.5    1.5
# 4         IT  associate    60.0    7.0
# 5      Sales  associate    55.0    2.5

# %%
employee.pivot_table(index=['Department', 'Title'], values=['Salary']).reset_index()
# Out:
#   Department      Title  Salary
# 0         HR         VP    70.0
# 1         HR    analyst    32.5
# 2         IT         VP    70.0
# 3         IT    analyst    32.5
# 4         IT  associate    60.0
# 5      Sales  associate    55.0

# %% [markdown]
# #### We want to display the number of years of work experience and the salary for each Title. Add Years as a column in your pivot table
# *Hint: Use Pandas doc(see References in README.md) to explore the pivot_table() arguments*

# %%
# your answer here
employee.pivot_table(index= ['Title']).reset_index()
# Out:
#        Title     Salary  Years
# 0         VP  70.000000   8.00
# 1    analyst  32.500000   2.25
# 2  associate  56.666667   4.00

# %% [markdown]
# #### We want to know the information about the mean salary and number of employees in each department and for each job title

# %%
# your answer here
employee.pivot_table (index= ['Department', 'Title'], values=['Salary', 'Name'], 
                      aggfunc = {'Name':'count', 'Salary':'mean'}).reset_index()
# Out:
#   Department      Title  Name  Salary
# 0         HR         VP     1    70.0
# 1         HR    analyst     2    32.5
# 2         IT         VP     1    70.0
# 3         IT    analyst     2    32.5
# 4         IT  associate     1    60.0
# 5      Sales  associate     2    55.0

# %%
#puede ser con sum o con count
employee.pivot_table (index= ['Department', 'Title'], values=['Salary', 'Name'], 
                      aggfunc = {'Name':'sum', 'Salary':'mean'}).reset_index()
# Out:
#   Department      Title        Name  Salary
# 0         HR         VP         Ana    70.0
# 1         HR    analyst  DavidSonia    32.5
# 2         IT         VP      Carlos    70.0
# 3         IT    analyst   JoseMaria    32.5
# 4         IT  associate       Pedro    60.0
# 5      Sales  associate   SamuelEva    55.0

# %% [markdown]
# #### We want to know for each department and for each job title the Salary's median,minimum,maximum and standard deviation. Comment your results

# %%
# your answer here
#No hay mucha diferencia entre el min, max y mean
employee.pivot_table (index= ['Title', 'Department'], values=['Salary'], aggfunc = (np.mean, np.min, np.max, np.std)).reset_index()
# Out:
#        Title Department Salary
#                           amax  amin  mean       std
# 0         VP         HR   70.0  70.0  70.0       NaN
# 1         VP         IT   70.0  70.0  70.0       NaN
# 2    analyst         HR   35.0  30.0  32.5  3.535534
# 3    analyst         IT   35.0  30.0  32.5  3.535534
# 4  associate         IT   60.0  60.0  60.0       NaN
# 5  associate      Sales   55.0  55.0  55.0  0.000000

# %%
#employee.pivot_table (index= ['Title', 'Department'], aggfunc = ({'Salary':'mean', 'Salary':'min', 'Salary':'max'}))
#No sé por qué no funciona así
min_max_mean_std_salary= employee.pivot_table (index= ['Title', 'Department'], aggfunc = ({'Salary':[min, max, np.mean, np.std]})).reset_index()
min_max_mean_std_salary
# Out:
#        Title Department Salary
#                            max  mean   min       std
# 0         VP         HR   70.0  70.0  70.0       NaN
# 1         VP         IT   70.0  70.0  70.0       NaN
# 2    analyst         HR   35.0  32.5  30.0  3.535534
# 3    analyst         IT   35.0  32.5  30.0  3.535534
# 4  associate         IT   60.0  60.0  60.0       NaN
# 5  associate      Sales   55.0  55.0  55.0  0.000000

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value

# %%
# your answer here
#min_max_mean_std_salary.at[0,'std']=0 Con esto iría uno por uno
#min_max_mean_std_salary

# %%
#min_max_mean_std_salary.fillna(0) #así no porque si no sale una nueva columna con std
min_max_mean_std_salary.fillna(0, inplace=True)
min_max_mean_std_salary
# Out:
#        Title Department Salary
#                            max  mean   min       std
# 0         VP         HR   70.0  70.0  70.0  0.000000
# 1         VP         IT   70.0  70.0  70.0  0.000000
# 2    analyst         HR   35.0  32.5  30.0  3.535534
# 3    analyst         IT   35.0  32.5  30.0  3.535534
# 4  associate         IT   60.0  60.0  60.0  0.000000
# 5  associate      Sales   55.0  55.0  55.0  0.000000

# %% [markdown]
# #### The stake holders want to know for each department the number of employees and how much money is spend on salaries. Could you provide that information?

# %%
# your answer here
#NO ENTIENDO LA DIFERENCIA ENTRE LOS SIGUIENTES, CUÁL ESTÁ MEJOR ESCRITO O ES CORRECTO?

employee.pivot_table(index=['Department'],aggfunc={'Salary':'sum', 'Name':'count'}).reset_index()
# Out:
#   Department  Name  Salary
# 0         HR     3     135
# 1         IT     4     195
# 2      Sales     2     110

# %%
employee.pivot_table(index=['Department'],values= ['Salary', 'Name'], aggfunc={'Salary':'sum', 'Name':'count'}).reset_index()
# Out:
#   Department  Name  Salary
# 0         HR     3     135
# 1         IT     4     195
# 2      Sales     2     110

# %% [markdown]
# #### For each Department and Title, we want to know the the total years of work experience and the mean salary

# %%
# your answer here
employee.pivot_table (index=['Department', 'Title'], values = ['Salary', 'Years'], aggfunc={'Years':'sum','Salary':'mean'}).reset_index()
# Out:
#   Department      Title  Salary  Years
# 0         HR         VP    70.0      8
# 1         HR    analyst    32.5      6
# 2         IT         VP    70.0      8
# 3         IT    analyst    32.5      3
# 4         IT  associate    60.0      7
# 5      Sales  associate    55.0      5

# %% [markdown]
# #### Bonus
#
# #### We now want to compute the mean salary after removing the maxima for each Department. Create the appropriate pivot table
#
# #### * Hint: Write a custom function*

# %%
# your answer here--Your custom function here

# %%
# your answer here

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Open the ` Fitbit.csv` file and name your dataset `fitbit`

# %%
# your answer here

fitbit = pd.read_csv('Fitbit.csv') 
fitbit.head(2)
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  08-05-2015            1934    905      0.65       0              1.355
# 1  09-05-2015            3631  18925     14.11       4            611.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
#
#    Activity Calories  MinutesOfSleep  MinutesOfBeingAwake  NumberOfAwakings  \
# 0               1680             384                   26                23
# 1               2248             454                   35                21
#
#    LengthOfRestInMinutes
# 0                    417
# 1                    491

# %% [markdown]
# #### Explore you dataset in terms of data types and descriptive statistics
# #### *Hint: Use Pandas functions from previous lectures*

# %%
# your answer here
fitbit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    367 non-null    object
#  1   Calorie burned          367 non-null    int64
#  2   Steps                   367 non-null    int64
#  3   Distance                367 non-null    float64
#  4   Floors                  367 non-null    int64
#  5   Minutes Sedentary       367 non-null    float64
#  6   Minutes Lightly Active  367 non-null    int64
#  7   Minutes Fairly Active   367 non-null    int64
#  8   Minutes Very Active     367 non-null    int64
#  9   Activity Calories       367 non-null    int64
#  10  MinutesOfSleep          367 non-null    int64
#  11  MinutesOfBeingAwake     367 non-null    int64
#  12  NumberOfAwakings        367 non-null    int64
#  13  LengthOfRestInMinutes   367 non-null    int64
# ...

# %%
# your answer here
fitbit.describe()
# Out:
#        Calorie burned         Steps    Distance      Floors  \
# count      367.000000    367.000000  367.000000  367.000000
# mean      2741.501362  10121.588556    8.549128   11.724796
# std        916.307036   5594.836225    3.409881   10.337370
# min        179.000000      0.000000    0.000000    0.000000
# 25%       2698.000000   6730.500000    6.155000    5.000000
# 50%       2974.000000  10413.000000    8.290000   11.000000
# 75%       3233.000000  13916.500000   10.560000   16.000000
# max       4351.000000  26444.000000   20.450000  101.000000
#
#        Minutes Sedentary  Minutes Lightly Active  Minutes Fairly Active  \
# count         367.000000              367.000000             367.000000
# mean          563.934482              236.405995              26.163488
# std           294.793145               86.531376              20.319456
# min             1.002000                0.000000               0.000000
# ...

# %% [markdown]
# #### You suspect that there must be a linear relationship between the Minutes Very Active and the Steps. Compute the correlation between these variables.

# %%
# your answer here 
fitbit.corr()
# Out:
#                         Calorie burned     Steps  Distance    Floors  \
# Calorie burned                1.000000  0.255305  0.292790  0.130757
# Steps                         0.255305  1.000000  0.779678  0.306511
# Distance                      0.292790  0.779678  1.000000  0.382940
# Floors                        0.130757  0.306511  0.382940  1.000000
# Minutes Sedentary             0.125353  0.076906  0.160632  0.057812
# Minutes Lightly Active        0.209540  0.393010  0.455272 -0.085992
# Minutes Fairly Active         0.188256  0.303244  0.348113  0.278408
# Minutes Very Active           0.197881  0.571452  0.759310  0.399503
# Activity Calories            -0.130758 -0.160568 -0.246853 -0.155532
# MinutesOfSleep                0.011485  0.130986  0.129442  0.069464
# MinutesOfBeingAwake           0.041999  0.124846  0.130447  0.064587
# NumberOfAwakings              0.030490  0.106591  0.091095  0.043459
# LengthOfRestInMinutes         0.017460  0.133405  0.134550  0.075864
#
# ...

# %%
fitbit[['Minutes Very Active','Steps']].corr()
# Out:
#                      Minutes Very Active     Steps
# Minutes Very Active             1.000000  0.571452
# Steps                           0.571452  1.000000

# %% [markdown]
# #### Use matplotlib to visually plot Minutes Very active vs Steps.
#
# ##### Hint : import matplotlib.pyplot as plt (See previous lessons)#####
# - Use plt.scatter(x=df['col_name_1'], y=df['col_name_2'])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x=fitbit['Minutes Very Active'], y=fitbit['Steps'],
            color = 'green',
            marker = '*', alpha = 0.7) #alpha >> opacidad
plt.xlabel('Min Very Act')
plt.ylabel('Steps')
plt.title ('Correlación')
# Out:
# Text(0.5, 1.0, 'Correlación')

# %% [markdown]
# #### What can you say about Minute Very Active and Steps? Write a comment below

# %%
#Correlación positiva, parece que entre 0 y 60 min es el mayor tiempo que una persona recorre pasos, parecería que no aguantamos
#más de una hora super activos jeje

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the Minutes Sedentary and the Steps. Compute the correlation between these variables.

# %%
fitbit[['Minutes Sedentary', 'Steps']].corr()
#la correlación es positiva pero tiende a cero, por lo tanto es casi nula
# Out:
#                    Minutes Sedentary     Steps
# Minutes Sedentary           1.000000  0.076906
# Steps                       0.076906  1.000000

# %% [markdown]
# #### Use matplotlib to visually plot Minutes Sedentary vs Steps. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
# your answer here}

plt.scatter(x=fitbit['Minutes Sedentary'], y=fitbit['Steps'], 
           color ='red', alpha = .3)
plt.xlabel ('Min Sedentary')
plt.ylabel ('Steps')
plt.title ('Correlación')
plt.show()

# %%
# Your comment here

#Definitivamente no hay minutos sedentarios mientras caminan jaja

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the MinutesOfSleep and the Steps. Compute the correlation between these variables.

# %%
# your answer here
fitbit[['MinutesOfSleep','Steps']].corr()
# Out:
#                 MinutesOfSleep     Steps
# MinutesOfSleep        1.000000  0.130986
# Steps                 0.130986  1.000000

# %% [markdown]
# #### Use matplotlib to visually plot MinutesOfSleep vs Steps. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
# your answer here
plt.scatter(x=fitbit['MinutesOfSleep'], y=fitbit['Steps'], marker='*', alpha = .4)
plt.xlabel ('MinutesSleep')
plt.ylabel('Steps')
plt.title('Correlación')
plt.show() #no sé bien para qué es esto, pero veo que se quitan los números de arriba jeje

# %% [markdown]
# #### Select a subset of your dataset with the columns below and compute the correlation matrix. Save the results in the variable `cor_fit`
# column= ['Calorie burned', 'Steps','Floors','Minutes Sedentary','Minutes Very Active', 'MinutesOfSleep']

# %%
# your answer here
subset= fitbit[['Calorie burned', 'Steps','Floors','Minutes Sedentary','Minutes Very Active', 'MinutesOfSleep']]
subset
# Out:
#      Calorie burned  Steps  Floors  Minutes Sedentary  Minutes Very Active  \
# 0              1934    905       0              1.355                    0
# 1              3631  18925       4            611.000                   60
# 2              3204  14228       1            602.000                   77
# 3              2673   6756       8            749.000                    4
# 4              2495    502       1            876.000                    0
# ..              ...    ...     ...                ...                  ...
# 362            3796  18588      16            599.000                   79
# 363            3525  16382      16            684.000                   55
# 364            3649  21913      19            701.000                   90
# 365            3539  19023      15            575.000                   85
# 366             304   9526       2            564.000                   10
#
#      MinutesOfSleep
# 0               384
# 1               454
# ...

# %%
#Print cor_fit
cor_fit=subset.corr()
cor_fit
# Out:
#                      Calorie burned     Steps    Floors  Minutes Sedentary  \
# Calorie burned             1.000000  0.255305  0.130757           0.125353
# Steps                      0.255305  1.000000  0.306511           0.076906
# Floors                     0.130757  0.306511  1.000000           0.057812
# Minutes Sedentary          0.125353  0.076906  0.057812           1.000000
# Minutes Very Active        0.197881  0.571452  0.399503           0.105963
# MinutesOfSleep             0.011485  0.130986  0.069464           0.204242
#
#                      Minutes Very Active  MinutesOfSleep
# Calorie burned                  0.197881        0.011485
# Steps                           0.571452        0.130986
# Floors                          0.399503        0.069464
# Minutes Sedentary               0.105963        0.204242
# Minutes Very Active             1.000000        0.108018
# MinutesOfSleep                  0.108018        1.000000

# %% [markdown]
# #### Based on the result of the correlation matrix. What are the highly correlated features with the variable Steps?
# *Hint: From the results above select the variable Steps and order your results in descending order (use Pandas sort_values function)*

# %%
# your answer here
#1. Minutes Very Active
#2. Floors
#3. Calorie burned

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the `Time_Grades.csv` file and name your dataset `time_grades`

# %%
# your answer here
time_grades=pd.read_csv('Time_Grades.csv')
time_grades.head(2)
# Out:
#     Name  Study time  Grade
# 0   Jose           4      4
# 1  Maria           9      7

# %% [markdown]
# #### Show visually the frequency distribution of the time_grades dataset.

# %%
# your answer here
time_grades.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Study time'}>,
#         <AxesSubplot:title={'center':'Grade'}>]], dtype=object)

# %% [markdown]
# #### Is there a correaltion between study time and Grade? Use both Pearson and Spearman correlation and comment your results.

# %%
# your answer here-Pearson 
time_grades.corr(method='pearson')
# Out:
#             Study time     Grade
# Study time    1.000000  0.798046
# Grade         0.798046  1.000000

# %%
## your answer here-Spearman
time_grades.corr(method='spearman')
# Out:
#             Study time     Grade
# Study time    1.000000  0.819659
# Grade         0.819659  1.000000

# %% [markdown]
# #### Use matplotlib to visually plot Study time vs Grade. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
# your answer here
plt.scatter (x=time_grades['Study time'], y=time_grades['Grade'])
plt.xlabel('Study Time')
plt.ylabel('Grade')
plt.show()

# %%
#your comment here
#Definitivamente estudiar menos de 7.5 horas no es recomendable, 
#pero tampoco es bueno estudiar más de 12.5 horas, porque muy pocos alcanzan buena calificación con eso, se necesita descanso
#aunque tampoco podemos decir cuál es el tiempo ideal de estudio porque entre 7.5 y 12.5 la calificación parece ser mediocre.

# %% [markdown]
# #### Could you explain the difference between Pearson and Spearman correlation? (see References in README.md)

# %%
#your comment here

'''
Pearson: Paramétrica (datos en nivel de medición de intervalo o razón, muestreo aleatorio) 
Evalúa la correalación lineal entre dos variables

Spearman: No paramétrica (datos de nivel ordinal, muestreo aleatorio )
    Evalúa la relación monotonica entre dos variables continuas u ordinales
'''
# Out:
# '\nPearson: Paramétrica (datos en nivel de medición de intervalo o razón, muestreo aleatorio) \nEvalúa la correalación lineal entre dos variables\n\nSpearman: No paramétrica (datos de nivel ordinal, muestreo aleatorio )\n    Evalúa la relación monotonica entre dos variables continuas u ordinales\n'
