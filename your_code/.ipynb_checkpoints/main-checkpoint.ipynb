# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Open the ` Employee.csv` file and name your dataset `employee`

# %%
# your answer here
employees = pd.read_csv('Employee.csv')
employees.head()
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55

# %% [markdown]
# #### What's the mean salary by department.
# ##### Tip : There are 2 ways to do it - one way is with and the other way is without pivot tables. Do it both ways.

# %%
# your answer here-1st way
#Utilizando un groupby en department y la media de salario
employees.groupby('Department')['Salary'].mean()
# Out:
# Department
# HR       45.00
# IT       48.75
# Sales    55.00
# Name: Salary, dtype: float64

# %%
# your answer here-2nd way
#con una pivto_table con index department y values salary donde por default calcula la media
employees.pivot_table(index = 'Department', values = 'Salary')
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %% [markdown]
# #### We want now to group the data by more than one column. Use Pandas pivot table function to select the mean salary by department and title

# %%
# your answer here
#pivto_table con index department y title y con values salary donde por default calcula la media
employees.pivot_table(index = ['Department','Title'], values = 'Salary')
# Out:
#                       Salary
# Department Title
# HR         VP           70.0
#            analyst      32.5
# IT         VP           70.0
#            analyst      32.5
#            associate    60.0
# Sales      associate    55.0

# %% [markdown]
# #### We want to display the number of years of work experience and the salary for each Title. Add Years as a column in your pivot table
# *Hint: Use Pandas doc(see References in README.md) to explore the pivot_table() arguments*

# %%
# your answer here
#pivot_table con index department y title, con years como columnas y con values salary donde por default calcula la media
#Agrego un fill_value vacío para que no muestre resultados en las combinaciones que no existen.
employees.pivot_table(index = ['Department','Title'], columns = ['Years'] ,values = 'Salary', fill_value = '')
# Out:
# Years                  1   2   3   4   7   8
# Department Title
# HR         VP                             70
#            analyst        30      35
# IT         VP                             70
#            analyst    35  30
#            associate                  60
# Sales      associate      55  55

# %% [markdown]
# #### We want to know the information about the mean salary and number of employees in each department and for each job title

# %%
# your answer here
#pivot_table con index department y title, y con agregaciones de media y conteo para salary y name, respectivamente.
employees.pivot_table(index = ['Department','Title'], aggfunc = {'Salary':np.mean, 'Name':'count'})
# Out:
#                       Name  Salary
# Department Title
# HR         VP            1    70.0
#            analyst       2    32.5
# IT         VP            1    70.0
#            analyst       2    32.5
#            associate     1    60.0
# Sales      associate     2    55.0

# %% [markdown]
# #### We want to know for each department and for each job title the Salary's median,minimum,maximum and standard deviation. Comment your results

# %%
# your answer here

#Primer intento
#employees.pivot_table(index = ['Department','Title'], values = ['Salary'], aggfunc = [np.mean,np.median,np.min,np.max,np.std])

#Segunod intento
#Agrega para la columna Salary, los calculos necesarios
employees.pivot_table(index = ['Department','Title'], aggfunc = {'Salary':[np.mean,np.median,np.min,np.max,np.std]})
# Out:
#                      Salary
#                        amax  amin  mean median       std
# Department Title
# HR         VP          70.0  70.0  70.0   70.0       NaN
#            analyst     35.0  30.0  32.5   32.5  3.535534
# IT         VP          70.0  70.0  70.0   70.0       NaN
#            analyst     35.0  30.0  32.5   32.5  3.535534
#            associate   60.0  60.0  60.0   60.0       NaN
# Sales      associate   55.0  55.0  55.0   55.0  0.000000

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value

# %%
# your answer here
#Agregao un fill_value con vacíos para aquellos valores que no se pueden calcular
employees.pivot_table(index = ['Department','Title'], aggfunc = {'Salary':[np.mean,np.median,np.min,np.max,np.std]}, fill_value = "")
# Out:
#                      Salary
#                        amax  amin  mean median      std
# Department Title
# HR         VP          70.0  70.0  70.0   70.0
#            analyst     35.0  30.0  32.5   32.5  3.53553
# IT         VP          70.0  70.0  70.0   70.0
#            analyst     35.0  30.0  32.5   32.5  3.53553
#            associate   60.0  60.0  60.0   60.0
# Sales      associate   55.0  55.0  55.0   55.0        0

# %% [markdown]
# #### The stake holders want to know for each department the number of employees and how much money is spend on salaries. Could you provide that information?

# %%
# your answer here
#Agrego un aggfunc para sumar los salrios y contar los nombres para saber cuantos empleados hay.
employees.pivot_table(index =  ['Department'], aggfunc = {'Salary':'sum','Name':'count'})
# Out:
#             Name  Salary
# Department
# HR             3     135
# IT             4     195
# Sales          2     110

# %% [markdown]
# #### For each Department and Title, we want to know the the total years of work experience and the mean salary

# %%
# your answer here
#Para cada department ytitle sumo los años y calculo la media del salrio
employees.pivot_table(index = ['Department','Title'], aggfunc = {'Years':'sum','Salary':'mean'})
# Out:
#                       Salary  Years
# Department Title
# HR         VP           70.0      8
#            analyst      32.5      6
# IT         VP           70.0      8
#            analyst      32.5      3
#            associate    60.0      7
# Sales      associate    55.0      5

# %% [markdown]
# #### Bonus
#
# #### We now want to compute the mean salary after removing the maxima for each Department. Create the appropriate pivot table
#
# #### * Hint: Write a custom function*

# %%
# your answer here--Your custom function here
def custom_mean(objeto : pd.Series):
    max_value = objeto.max()
    objeto.drop(objeto[objeto == max_value].index[0], inplace =  True)
    return objeto.mean()

# %%
# your answer here
employees.pivot_table(index = ['Department'], values = 'Salary', aggfunc = custom_mean)
# Out:
#                Salary
# Department
# HR          32.500000
# IT          41.666667
# Sales       55.000000

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Open the ` Fitbit.csv` file and name your dataset `fitbit`

# %%
# your answer here
fitbit = pd.read_csv('Fitbit.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  08-05-2015            1934    905      0.65       0              1.355
# 1  09-05-2015            3631  18925     14.11       4            611.000
# 2  10-05-2015            3204  14228     10.57       1            602.000
# 3  11-05-2015            2673   6756      5.02       8            749.000
# 4  12-05-2015            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  MinutesOfSleep  MinutesOfBeingAwake  NumberOfAwakings  \
# ...

# %% [markdown]
# #### Explore you dataset in terms of data types and descriptive statistics
# #### *Hint: Use Pandas functions from previous lectures*

# %%
# your answer here
fitbit.dtypes
# Out:
# Date                       object
# Calorie burned              int64
# Steps                       int64
# Distance                  float64
# Floors                      int64
# Minutes Sedentary         float64
# Minutes Lightly Active      int64
# Minutes Fairly Active       int64
# Minutes Very Active         int64
# Activity Calories           int64
# MinutesOfSleep              int64
# MinutesOfBeingAwake         int64
# NumberOfAwakings            int64
# LengthOfRestInMinutes       int64
# dtype: object

# %%
# your answer here
fitbit.describe().T
# Out:
#                         count          mean          std      min       25%  \
# Calorie burned          367.0   2741.501362   916.307036  179.000  2698.000
# Steps                   367.0  10121.588556  5594.836225    0.000  6730.500
# Distance                367.0      8.549128     3.409881    0.000     6.155
# Floors                  367.0     11.724796    10.337370    0.000     5.000
# Minutes Sedentary       367.0    563.934482   294.793145    1.002   520.000
# Minutes Lightly Active  367.0    236.405995    86.531376    0.000   179.000
# Minutes Fairly Active   367.0     26.163488    20.319456    0.000     8.000
# Minutes Very Active     367.0     35.722071    31.006682    0.000    10.500
# Activity Calories       367.0   2044.147139  2041.267168    0.000  1218.500
# MinutesOfSleep          367.0    290.479564   154.752328    0.000   224.000
# MinutesOfBeingAwake     367.0     28.008174    18.541415    0.000    14.000
# ...

# %% [markdown]
# #### You suspect that there must be a linear relationship between the Minutes Very Active and the Steps. Compute the correlation between these variables.

# %%
# your answer here
fitbit['Minutes Very Active'].corr(fitbit['Steps'])
# Out:
# 0.5714518481062608

# %% [markdown]
# #### Use matplotlib to visually plot Minutes Very active vs Steps.
#
# ##### Hint : import matplotlib.pyplot as plt (See previous lessons)#####
# - Use plt.scatter(x=df['col_name_1'], y=df['col_name_2'])

# %%
# your answer here
import matplotlib.pyplot as plt

plt.scatter(x = fitbit['Minutes Very Active'], y = fitbit['Steps'])

# %% [markdown]
# #### What can you say about Minute Very Active and Steps? Write a comment below

# %%
# your comment here
#Se observa una correlación positiva donde a mayor minutos activos, mayor número de pasos
# con algunos casos atípicos donde esto no se cumple.

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the Minutes Sedentary and the Steps. Compute the correlation between these variables.

# %%
# your answer here
fitbit['Minutes Sedentary'].corr(fitbit['Steps'])
# Out:
# 0.07690608062990091

# %% [markdown]
# #### Use matplotlib to visually plot Minutes Sedentary vs Steps. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
# your answer here
plt.scatter(x = fitbit['Minutes Sedentary'], y = fitbit['Steps'])

# %%
# Your comment here
#Se observan tres grupos principales, donde el que predomina es aquel que tiene datos demasiados dispersos.

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the MinutesOfSleep and the Steps. Compute the correlation between these variables.

# %%
# your answer here
fitbit['MinutesOfSleep'].corr(fitbit['Steps'])
# Out:
# 0.1309856595083638

# %% [markdown]
# #### Use matplotlib to visually plot MinutesOfSleep vs Steps. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
# your answer 
plt.scatter(x = fitbit['MinutesOfSleep'], y = fitbit['Steps'])

# %% [markdown]
# #### Select a subset of your dataset with the columns below and compute the correlation matrix. Save the results in the variable `cor_fit`
# column= ['Calorie burned', 'Steps','Floors','Minutes Sedentary','Minutes Very Active', 'MinutesOfSleep']

# %%
# your answer here
cor_fit = fitbit[ ['Calorie burned', 'Steps','Floors','Minutes Sedentary','Minutes Very Active', 'MinutesOfSleep']].corr()

# %%
#Print cor_fit
cor_fit
# Out:
#                      Calorie burned     Steps    Floors  Minutes Sedentary  \
# Calorie burned             1.000000  0.255305  0.130757           0.125353
# Steps                      0.255305  1.000000  0.306511           0.076906
# Floors                     0.130757  0.306511  1.000000           0.057812
# Minutes Sedentary          0.125353  0.076906  0.057812           1.000000
# Minutes Very Active        0.197881  0.571452  0.399503           0.105963
# MinutesOfSleep             0.011485  0.130986  0.069464           0.204242
#
#                      Minutes Very Active  MinutesOfSleep
# Calorie burned                  0.197881        0.011485
# Steps                           0.571452        0.130986
# Floors                          0.399503        0.069464
# Minutes Sedentary               0.105963        0.204242
# Minutes Very Active             1.000000        0.108018
# MinutesOfSleep                  0.108018        1.000000

# %% [markdown]
# #### Based on the result of the correlation matrix. What are the highly correlated features with the variable Steps?
# *Hint: From the results above select the variable Steps and order your results in descending order (use Pandas sort_values function)*

# %%
# your answer here
cor_fit['Steps'].sort_values(ascending =  False)
# Out:
# Steps                  1.000000
# Minutes Very Active    0.571452
# Floors                 0.306511
# Calorie burned         0.255305
# MinutesOfSleep         0.130986
# Minutes Sedentary      0.076906
# Name: Steps, dtype: float64

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the `Time_Grades.csv` file and name your dataset `time_grades`

# %%
# your answer here
time_grades = pd.read_csv('Time_Grades.csv')

# %%
#Print time_grades
time_grades.head()
# Out:
#      Name  Study time  Grade
# 0    Jose           4      4
# 1   Maria           9      7
# 2   David           8      9
# 3   Sonia          10      7
# 4  Samuel          20      9

# %% [markdown]
# #### Show visually the frequency distribution of the time_grades dataset.

# %%
time_grades['Grade'].value_counts()
#plt.bar(time_grades['Grade'])
# Out:
# 7    4
# 9    3
# 8    2
# 3    2
# 5    1
# 4    1
# 2    1
# 1    1
# Name: Grade, dtype: int64

# %% [markdown]
# #### Is there a correaltion between study time and Grade? Use both Pearson and Spearman correlation and comment your results.

# %%
# your answer here-Pearson 
time_grades['Grade'].corr(time_grades['Study time'])
# Out:
# 0.7980456073578858

# %%
## your answer here-Spearman
time_grades['Grade'].corr(time_grades['Study time'], method = 'spearman')
# Out:
# 0.819658753036942

# %%
# your answer here
plt.scatter(x = time_grades['Grade'], y = time_grades['Study time'])

# %%
#your comment here
#Se observa que a mayor número de horas de estudio, mayor calificación.

# %% [markdown]
# #### Could you explain the difference between Pearson and Spearman correlation? (see References in README.md)

# %%
#your comment here
# La correlación de Spearman entre dos variables es igual a la correlación de Pearson 
# entre los valores de rango de esas dos variables; mientras que la correlación de 
# Pearson evalúa las relaciones lineales, la correlación de Spearman evalúa las 
# relaciones monótonas (ya sean lineales o no).
