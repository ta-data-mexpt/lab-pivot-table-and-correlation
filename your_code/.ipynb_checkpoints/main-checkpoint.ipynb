# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Open the ` Employee.csv` file and name your dataset `employee`

# %%
# your answer here

employee = pd.read_csv('employee.csv')

# %%
employee.head()
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55

# %% [markdown]
# #### What's the mean salary by department.
# ##### Tip : There are 2 ways to do it - one way is with and the other way is without pivot tables. Do it both ways.

# %%
# your answer here-1st way
employee.groupby(['Department']).agg({'Salary':'mean'})
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %%
# your answer here-2nd way
employee.pivot_table(index=["Department"], values=["Salary"], aggfunc=np.mean)
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %% [markdown]
# #### We want now to group the data by more than one column. Use Pandas pivot table function to select the mean salary by department and title

# %%
# your answer here
employee.pivot_table(index=["Department","Title"], values=["Salary"], aggfunc=np.mean)
# Out:
#                       Salary
# Department Title
# HR         VP           70.0
#            analyst      32.5
# IT         VP           70.0
#            analyst      32.5
#            associate    60.0
# Sales      associate    55.0

# %% [markdown]
# #### We want to display the number of years of work experience and the salary for each Title. Add Years as a column in your pivot table
# *Hint: Use Pandas doc(see References in README.md) to explore the pivot_table() arguments*

# %%
# your answer here
employee.pivot_table(index=["Department","Title"], columns=['Years'], values=["Salary"])
# Out:
#                      Salary
# Years                     1     2     3     4     7     8
# Department Title
# HR         VP           NaN   NaN   NaN   NaN   NaN  70.0
#            analyst      NaN  30.0   NaN  35.0   NaN   NaN
# IT         VP           NaN   NaN   NaN   NaN   NaN  70.0
#            analyst     35.0  30.0   NaN   NaN   NaN   NaN
#            associate    NaN   NaN   NaN   NaN  60.0   NaN
# Sales      associate    NaN  55.0  55.0   NaN   NaN   NaN

# %% [markdown]
# #### We want to know the information about the mean salary and number of employees in each department and for each job title

# %%
# your answer here
employee.pivot_table(index=["Department","Title"], values=["Salary", 'Name'], aggfunc = {'Salary':np.mean, 'Name': 'count'})
# Out:
#                       Name  Salary
# Department Title
# HR         VP            1    70.0
#            analyst       2    32.5
# IT         VP            1    70.0
#            analyst       2    32.5
#            associate     1    60.0
# Sales      associate     2    55.0

# %% [markdown]
# #### We want to know for each department and for each job title the Salary's median,minimum,maximum and standard deviation. Comment your results

# %%
# your answer here
employee.pivot_table(index=["Department"], values=["Salary"], aggfunc = ['min', 'max', 'median', np.std])
# Out:
#               min    max median        std
#            Salary Salary Salary     Salary
# Department
# HR             30     70   35.0  21.794495
# IT             30     70   47.5  19.311050
# Sales          55     55   55.0   0.000000

# %%
employee.pivot_table(index=["Title"], values=["Salary"], aggfunc = ['min', 'max', 'median', np.std])
# Out:
#              min    max median       std
#           Salary Salary Salary    Salary
# Title
# VP            70     70   70.0  0.000000
# analyst       30     35   32.5  2.886751
# associate     55     60   55.0  2.886751

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value

# %%
# your answer here
#No identfique que faltaran datos

# %% [markdown]
# #### The stake holders want to know for each department the number of employees and how much money is spend on salaries. Could you provide that information?

# %%
# your answer here
employee.pivot_table(index=["Department"], values=["Salary", 'Name'], aggfunc = {'Salary':'sum', 'Name': 'count'})
# Out:
#             Name  Salary
# Department
# HR             3     135
# IT             4     195
# Sales          2     110

# %% [markdown]
# #### For each Department and Title, we want to know the the total years of work experience and the mean salary

# %%
# your answer here
employee.pivot_table(index=["Department", "Title"], values=["Salary", 'Years'], aggfunc = {'Years':'sum', 'Salary': np.mean})
# Out:
#                       Salary  Years
# Department Title
# HR         VP           70.0      8
#            analyst      32.5      6
# IT         VP           70.0      8
#            analyst      32.5      3
#            associate    60.0      7
# Sales      associate    55.0      5

# %% [markdown]
# #### Bonus
#
# #### We now want to compute the mean salary after removing the maxima for each Department. Create the appropriate pivot table
#
# #### * Hint: Write a custom function*

# %%
# your answer here--Your custom function here

# %%
# your answer here

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Open the ` Fitbit.csv` file and name your dataset `fitbit`

# %%
# your answer here
fitbit = pd.read_csv('Fitbit.csv')

# %% [markdown]
# #### Explore you dataset in terms of data types and descriptive statistics
# #### *Hint: Use Pandas functions from previous lectures*

# %%
# your answer here
fitbit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    367 non-null    object
#  1   Calorie burned          367 non-null    int64
#  2   Steps                   367 non-null    int64
#  3   Distance                367 non-null    float64
#  4   Floors                  367 non-null    int64
#  5   Minutes Sedentary       367 non-null    float64
#  6   Minutes Lightly Active  367 non-null    int64
#  7   Minutes Fairly Active   367 non-null    int64
#  8   Minutes Very Active     367 non-null    int64
#  9   Activity Calories       367 non-null    int64
#  10  MinutesOfSleep          367 non-null    int64
#  11  MinutesOfBeingAwake     367 non-null    int64
#  12  NumberOfAwakings        367 non-null    int64
#  13  LengthOfRestInMinutes   367 non-null    int64
# ...

# %%
# your answer here
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  08-05-2015            1934    905      0.65       0              1.355
# 1  09-05-2015            3631  18925     14.11       4            611.000
# 2  10-05-2015            3204  14228     10.57       1            602.000
# 3  11-05-2015            2673   6756      5.02       8            749.000
# 4  12-05-2015            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  MinutesOfSleep  MinutesOfBeingAwake  NumberOfAwakings  \
# ...

# %% [markdown]
# #### You suspect that there must be a linear relationship between the Minutes Very Active and the Steps. Compute the correlation between these variables.

# %%
# your answer here
fitbit['Minutes Very Active'].corr(fitbit['Steps'])
# Out:
# 0.5714518481062605

# %% [markdown]
# #### Use matplotlib to visually plot Minutes Very active vs Steps.
#
# ##### Hint : import matplotlib.pyplot as plt (See previous lessons)#####
# - Use plt.scatter(x=df['col_name_1'], y=df['col_name_2'])

# %%
# your answer here
import matplotlib.pyplot as plt

# %%
x = fitbit['Minutes Very Active']
y = fitbit['Steps']
plt.scatter(x,y)

# %% [markdown]
# #### What can you say about Minute Very Active and Steps? Write a comment below

# %%
# your comment here
#Existe una relacion, entre mas pasos hay mas actividad hay.

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the Minutes Sedentary and the Steps. Compute the correlation between these variables.

# %%
# your answer here
fitbit['Minutes Sedentary'].corr(fitbit['Steps'])
# Out:
# 0.07690608062990092

# %% [markdown]
# #### Use matplotlib to visually plot Minutes Sedentary vs Steps. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
# your answer here
x= fitbit['Minutes Sedentary']

plt.scatter(x,y)

# %%
# Your comment here
#Entre mas minutos esten de sendentarios menos pasos dan

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the MinutesOfSleep and the Steps. Compute the correlation between these variables.

# %%
# your answer here

fitbit['MinutesOfSleep'].corr(fitbit['Steps'])
# Out:
# 0.13098565950836388

# %% [markdown]
# #### Use matplotlib to visually plot MinutesOfSleep vs Steps. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
# your answer here
x= fitbit['MinutesOfSleep']

plt.scatter(x,y)

# %% [markdown]
# #### Select a subset of your dataset with the columns below and compute the correlation matrix. Save the results in the variable `cor_fit`
# column= ['Calorie burned', 'Steps','Floors','Minutes Sedentary','Minutes Very Active', 'MinutesOfSleep']

# %%
# your answer here
column= ['Calorie burned', 'Steps','Floors','Minutes Sedentary','Minutes Very Active', 'MinutesOfSleep']
subset = fitbit[column]
cor_fit=subset.corr()

# %%
#Print cor_fit
cor_fit
# Out:
#                      Calorie burned     Steps    Floors  Minutes Sedentary  \
# Calorie burned             1.000000  0.255305  0.130757           0.125353
# Steps                      0.255305  1.000000  0.306511           0.076906
# Floors                     0.130757  0.306511  1.000000           0.057812
# Minutes Sedentary          0.125353  0.076906  0.057812           1.000000
# Minutes Very Active        0.197881  0.571452  0.399503           0.105963
# MinutesOfSleep             0.011485  0.130986  0.069464           0.204242
#
#                      Minutes Very Active  MinutesOfSleep
# Calorie burned                  0.197881        0.011485
# Steps                           0.571452        0.130986
# Floors                          0.399503        0.069464
# Minutes Sedentary               0.105963        0.204242
# Minutes Very Active             1.000000        0.108018
# MinutesOfSleep                  0.108018        1.000000

# %% [markdown]
# #### Based on the result of the correlation matrix. What are the highly correlated features with the variable Steps?
# *Hint: From the results above select the variable Steps and order your results in descending order (use Pandas sort_values function)*

# %%
# your answer here
st_sorted= cor_fit.sort_values(by="Steps", ascending = False)
st_sorted[['Steps']]
# Out:
#                         Steps
# Steps                1.000000
# Minutes Very Active  0.571452
# Floors               0.306511
# Calorie burned       0.255305
# MinutesOfSleep       0.130986
# Minutes Sedentary    0.076906

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the `Time_Grades.csv` file and name your dataset `time_grades`

# %%
# your answer here
time_grades = pd.read_csv ('Time_Grades.csv')

# %%
#Print time_grades
time_grades
# Out:
#         Name  Study time  Grade
# 0       Jose           4      4
# 1      Maria           9      7
# 2      David           8      9
# 3      Sonia          10      7
# 4     Samuel          20      9
# 5        Eva           5      3
# 6     Carlos          12      7
# 7      Pedro           6      5
# 8        Ana          18      9
# 9   Gervasio           7      3
# 10     Gemma           7      8
# 11    Alicia          11      7
# 12  Jonathan           2      1
# 13  Cristina          13      8
# 14     Pilar           3      2

# %% [markdown]
# #### Show visually the frequency distribution of the time_grades dataset.

# %%
# your answer here
time_grades.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Is there a correaltion between study time and Grade? Use both Pearson and Spearman correlation and comment your results.

# %%
# your answer here-Pearson 
time_grades[['Study time','Grade']].corr('pearson')
# Out:
#             Study time     Grade
# Study time    1.000000  0.798046
# Grade         0.798046  1.000000

# %%
## your answer here-Spearman
time_grades[['Study time','Grade']].corr('spearman')
# Out:
#             Study time     Grade
# Study time    1.000000  0.819659
# Grade         0.819659  1.000000

# %% [markdown]
# #### Use matplotlib to visually plot Study time vs Grade. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
# your answer here
x = time_grades['Study time']
y = time_grades['Grade']
plt.scatter(x,y)

# %%
#your comment here
#Entre mas tiempo de estudio exista mejor es la calificacion

# %% [markdown]
# #### Could you explain the difference between Pearson and Spearman correlation? (see References in README.md)

# %%
#your comment here
#Person es para datos que estan estrechamente relacionados y tiene dependencia uno con el otro
#Spearman son para datos que no estan estrachemente relacion y no tienen dependencia uno con el otro
